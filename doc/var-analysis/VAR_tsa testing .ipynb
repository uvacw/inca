# %%
from analysis import VAR_tsa as tsa

# %%
fin_model = tsa.VAR()

# %%
res = m.fit(queries=['financial','crisis'], timefield = 'META.ADDED', granularity = 'day',ic='')
# Out:
# Before fitting, I automatically check stationarity assumption
# You are good to go

# %%
m.plot('lag')
# Out:
# Lag plot where y is 1. financial
# Lag plot where y is 2. crisis
